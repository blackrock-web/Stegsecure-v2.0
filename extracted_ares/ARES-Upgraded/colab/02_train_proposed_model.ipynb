# %% [markdown]
# # Train ARES-Steg-Q Residual CNN (Google Colab)
#
# Runtime → Change runtime type → GPU (T4/L4/A100).
#
# This trains the HiDDeN-style residual compensator. Payload LSBs remain CRC-protected and are never modified by the network.

# %%
# !pip install -q torch torchvision Pillow cryptography numpy
import torch
print('CUDA:', torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# %%
# Upload ares_steg_quantum.py from the project, or paste the module.
# Then:
from ares_steg_quantum import train_residual_cnn
model, history = train_residual_cnn(
    epochs=20, batch_size=8, size=128, lr=1e-3,
    save_path='proposed_model.pt'
)
print('Saved proposed_model.pt')
# Download proposed_model.pt and place under models/proposed/
